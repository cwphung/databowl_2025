# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from model import ReachabilityModel

# %% [markdown]
# #### Create Array of Pandas Dataframes for each CSV File in Dataset

# %%
dfs = []
datapath = os.getcwd() + '\data'
for item in os.listdir(datapath):
    fullpath = os.path.join(datapath, item)
    if os.path.isfile(fullpath):
        dfs.append(pd.read_csv('data/' + item))
# Out:
# C:\Users\cwphu\AppData\Local\Temp\ipykernel_26232\3426312423.py:6: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv('data/' + item))

# %% [markdown]
# #### Clean Each Input/Output DF and Generate Player Name -> Player ID Dictionary

# %%
def cleanInputData(df):
    cleandf = df.copy()
    cleandf = cleandf[cleandf['player_to_predict']==True]
    cleandf['unique_play_id'] = cleandf['game_id'].astype(str) + cleandf['play_id'].astype(str)
    cleandf = cleandf.drop(columns=['game_id', 'play_id', 'player_to_predict', 'player_birth_date', 'player_position'])
    cleandf['v_x'] = np.sin(cleandf['dir']*2*np.pi/360.0) * cleandf['s']
    cleandf['v_y'] = np.cos(cleandf['dir']*2*np.pi/360.0) * cleandf['s']
    cleandf['a_x'] = np.sin(cleandf['dir']*2*np.pi/360.0) * cleandf['a']
    cleandf['a_y'] = np.cos(cleandf['dir']*2*np.pi/360.0) * cleandf['a']
    cleandf = cleandf.drop(columns=['s', 'a', 'dir'])
    return cleandf

def cleanOutputData(df):
    cleandf = df.copy()
    cleandf['unique_play_id'] = cleandf['game_id'].astype(str) + cleandf['play_id'].astype(str)
    cleandf = cleandf.drop(columns=['game_id', 'play_id'])
    return cleandf

# %%
clean_input_dfs = []
for i in range(0, 18):
    clean_input_dfs.append(cleanInputData(dfs[i]))
clean_output_dfs = []
for i in range(18, 36):
    clean_output_dfs.append(cleanOutputData(dfs[i]))

# %%
player_dict = dict()
max_play_len = 0
for clean_dfs in clean_input_dfs:
    for _,row in clean_dfs.iterrows():
        id = row['nfl_id']
        max_play_len = max(max_play_len, row['frame_id'])
        if id not in player_dict:
            name = row['player_name']
            player_dict[id] = name

# %%
player_dict
# Out:
# {46137: 'Justin Reid',
#  52546: "L'Jarius Sneed",
#  44930: 'Josh Reynolds',
#  44888: 'Alex Anzalone',
#  55910: 'Brian Branch',
#  53953: 'Jerry Jacobs',
#  54653: 'Malcolm Rodriguez',
#  41325: 'Jerick McKinnon',
#  53591: 'Noah Gray',
#  47882: 'Mike Edwards',
#  38696: 'Marvin Jones',
#  53487: 'Nick Bolton',
#  53541: 'Amon-Ra St. Brown',
#  54527: 'Bryan Cook',
#  52471: 'Willie Gay Jr.',
#  54568: 'Leo Chenal',
#  47888: 'C.J. Gardner-Johnson',
#  44906: 'Cameron Sutton',
#  54562: 'Kerby Joseph',
#  46213: 'Justin Watson',
#  55882: 'Jack Campbell',
#  46243: 'Marquez Valdes-Scantling',
#  55920: 'Rashee Rice',
#  53959: 'Brock Wright',
#  54486: 'Trent McDuffie',
#  52585: 'Michael Danna',
#  55899: 'Sam LaPorta',
#  55876: 'Jahmyr Gibbs',
#  54511: 'Joshua Paschal',
#  47913: 'Drue Tranquill',
#  46309: 'Richie James',
#  42460: 'Blake Bell',
#  55895: 'Felix Anudike-Uzomah',
#  54600: 'Joshua Williams',
#  53449: 'Kadarius Toney',
#  54716: 'Isiah Pacheco',
#  54519: 'Skyy Moore',
#  43584: 'Kalif Raymond',
#  44834: 'Charles Harris',
#  52440: 'Clyde Edwards-Helaire',
#  54495: 'George Karlaftis',
#  54885: 'Justyn Ross',
#  52424: 'A.J. Terrell',
#  52272: 'Dee Alford',
#  46123: 'Jessie Bates',
#  48027: 'Kaden Elliss',
#  53488: 'Terrace Marshall Jr.',
#  53469: 'Richie Grant',
#  54523: 'Troy Andersen',
#  46094: 'Hayden Hurst',
#  53555: 'Chuba Hubbard',
#  52472: 'Jeremy Chinn',
#  42368: 'Shaq Thompson',
#  54473: 'Drake London',
#  46527: 'Frankie Luvu',
#  53437: 'Jaycee Horn',
#  43350: 'Vonn Bell',
#  44931: 'Mack Hollins',
#  46215: 'Tre Flowers',
#  40488: 'Adam Thielen',
#  55904: 'Jonathan Mingo',
#  46124: 'Donte Jackson',
#  42816: 'Troy Hill',
#  55872: 'Bijan Robinson',
#  52858: 'Giovanni Ricci',
#  54503: 'Arnold Ebiketie',
#  45004: 'Xavier Woods',
#  53433: 'Kyle Pitts',
#  47836: 'Miles Sanders',
#  54616: 'Tyler Allgeier',
#  52417: 'C.J. Henderson',
#  52542: 'Jaylinn Hawkins',
#  54604: 'Isaiah Likely',
#  42393: 'Ronald Darby',
#  54572: 'Dameon Pierce',
#  54468: 'Derek Stingley Jr.',
#  56032: "Henry To'oTo'o",
#  54502: 'Jalen Pitre',
#  55886: 'Zay Flowers',
#  42441: 'Steven Nelson',
#  54479: 'Kyle Hamilton',
#  46206: 'Dalton Schultz',
#  46672: 'Tavierre Thomas',
#  53533: 'Brandon Stephens',
#  52627: 'Geno Stone',
#  44854: 'Marcus Williams',
#  46077: 'Roquan Smith',
#  53518: 'Nico Collins',
#  53456: 'Rashod Bateman',
#  52506: 'Malik Harrison',
#  39989: 'Robert Woods',
#  53819: "Ar'Darius Washington",
#  52436: 'Patrick Queen',
#  41238: 'Odell Beckham',
#  55934: 'Tank Dell',
#  46461: 'Mike Boone',
#  54540: 'Christian Harris',
#  46122: 'M.J. Stewart',
#  43395: 'Eric Murray',
#  44902: 'Shaquill Griffin',
#  42391: 'Denzel Perryman',
#  52463: 'J.K. Dobbins',
#  54510: 'David Ojabo',
#  53460: 'Odafe Oweh',
#  54593: 'Charlie Kolar',
#  54635: 'Teagan Quitoriano',
#  52897: 'Grayland Arnold',
#  45052: 'Noah Brown',
#  56070: 'Xavier Hutchinson',
#  53455: 'Greg Newsome II',
#  54533: 'Martin Emerson',
#  53434: "Ja'Marr Chase",
#  54496: 'Daxton Hill',
#  46104: 'Nick Chubb',
#  46073: 'Denzel Ward',
#  52452: 'Grant Delpit',
#  47833: 'Irv Smith',
#  54525: 'Cam Taylor-Britt',
#  48026: 'Nick Scott',
#  40026: 'Marquise Goodwin',
#  43344: 'Tyler Boyd',
#  53540: 'Cameron Sample',
#  52515: 'Akeem Davis-Gaither',
#  52473: 'Logan Wilson',
#  42347: 'Amari Cooper',
#  44872: 'Chidobe Awuzie',
#  55925: 'DJ Turner II',
#  53463: 'Elijah Moore',
#  44860: 'Joe Mixon',
#  46138: 'B.J. Hill',
#  43641: 'Mike Hilton',
#  38843: 'Rodney McLeod',
#  52441: 'Tee Higgins',
#  44841: 'David Njoku',
#  47855: 'Germaine Pratt',
#  52595: 'Donovan Peoples-Jones',
#  54564: 'David Bell',
#  44915: 'Trey Hendrickson',
#  56405: 'Ronnie Hickman Jr.',
#  53481: 'Jeremiah Owusu-Koramoah',
#  52523: 'Harrison Bryant',
#  44813: 'Myles Garrett',
#  44974: 'Anthony Walker',
#  53631: 'Chris Evans',
#  42465: "Za'Darius Smith",
#  46167: 'Jordan Akins',
#  54492: 'Devin Lloyd',
#  44926: 'Rayshawn Jenkins',
#  53462: 'Tyson Campbell',
#  54657: 'Andrew Ogletree',
#  46304: 'Zaire Franklin',
#  44849: 'Zay Jones',
#  52493: 'Julian Blackmon',
#  46105: 'Shaquille Leonard',
#  44835: 'Evan Engram',
#  55137: 'Darrell Baker Jr.',
#  46095: 'Calvin Ridley',
#  54466: 'Travon Walker',
#  55944: 'Josh Downs',
#  46116: 'Christian Kirk',
#  54980: 'Dallis Flowers',
#  54704: 'Rodney Thomas',
#  53703: 'Deon Jackson',
#  53556: 'Kylen Granson',
#  53494: 'Andre Cisco',
#  47947: 'E.J. Speed',
#  45287: 'Kenny Moore II',
#  46724: 'Tony Brown',
#  55953: 'Tank Bigsby',
#  46456: 'Darious Williams',
#  46269: 'Foye Oluokun',
#  47790: 'Josh Hines-Allen',
#  44792: 'Mo Alie-Cox',
#  48508: 'Andrew Wingard',
#  56041: 'Evan Hull',
#  54518: 'Alec Pierce',
#  52442: 'Michael Pittman',
#  53454: 'Travis Etienne',
#  53662: 'Jake Funk',
#  52453: 'Antoine Winfield Jr.',
#  46132: 'Carlton Davis III',
#  47788: 'Devin White',
#  38588: 'Lavonte David',
#  52430: 'Justin Jefferson',
#  54583: 'Akayleb Evans',
#  53554: 'Camryn Bynum',
#  52613: 'Josh Metellus',
#  54683: 'Ko Kieft',
#  54556: 'Rachaad White',
#  56540: 'Christian Izien',
#  53461: 'Joe Tryon-Shoyinka',
#  43971: 'C.J. Ham',
#  47890: 'Anthony Nelson',
#  47791: 'T.J. Hockenson',
#  47885: 'Alexander Mattison',
#  47816: 'Byron Murphy',
#  44896: 'Chris Godwin Jr.',
#  38559: 'Harrison Smith',
#  42427: 'Jordan Hicks',
#  54571: 'Cade Otton',
#  55967: 'Mekhi Blackmon',
#  41233: 'Mike Evans',
#  47852: 'Josh Oliver',
#  54531: 'Brian Asamoah II',
#  55887: 'Jordan Addison',
#  46711: 'Ryan Neal',
#  47877: 'Jamel Dean',
#  52584: 'K.J. Osborn',
#  56056: 'Trey Palmer',
#  41915: 'Shaquil Barrett',
#  56527: 'Ivan Pace Jr.',
#  55075: 'Deven Thompkins',
#  53519: 'Patrick Jones II',
#  56663: 'Sean Tucker',
#  53505: 'Paulson Adebo',
#  53489: 'Pete Werner',
#  54608: 'Chig Okonkwo',
#  40017: 'Tyrann Mathieu',
#  55946: 'Tyjae Spears',
#  47899: 'Amani Hooker',
#  52469: 'Kristian Fulton',
#  43336: 'Michael Thomas',
#  46110: 'Harold Landry III',
#  44947: 'Jamaal Williams',
#  48268: 'Azeez Al-Shaair',
#  53529: 'Elijah Molden',
#  54500: 'Roger McCreary',
#  47822: 'Sean Murphy-Bunting',
#  44823: 'Marshon Lattimore',
#  39973: 'DeAndre Hopkins',
#  44851: 'Marcus Maye',
#  54514: 'Alontae Taylor',
#  53074: 'Nick Westbrook-Ikhine',
#  52942: 'Juwan Johnson',
#  54476: 'Chris Olave',
#  38607: 'Demario Davis',
#  56011: 'Jordan Howden',
#  43353: 'Kevin Byard',
#  55133: 'Rashid Shaheed',
#  46168: 'Isaac Yiadom',
#  43396: 'Chris Moore',
#  55184: 'Jack Gibbens',
#  54483: 'Treylon Burks',
#  47915: 'Ugo Amadi',
#  48537: 'Carl Granderson',
#  53601: 'Deommodore Lenoir',
#  46139: 'Fred Warner',
#  54517: 'George Pickens',
#  47956: 'Cole Holcomb',
#  43503: 'Elandon Roberts',
#  37078: 'Patrick Peterson',
#  47819: 'Deebo Samuel Sr.',
#  44959: 'George Kittle',
#  44962: 'Damontae Kazee',
#  43306: 'Keanu Neal',
#  52433: 'Brandon Aiyuk',
#  46757: 'Charvarius Ward',
#  53609: 'Talanoa Hufanga',
#  38868: 'Tashaun Gipson',
#  47849: 'Diontae Johnson',
#  42467: 'Kwon Alexander',
#  46698: 'Levi Wallace',
#  46080: 'Minkah Fitzpatrick',
#  52625: 'Jauan Jennings',
#  41290: 'Allen Robinson',
#  44842: 'T.J. Watt',
#  44820: 'Christian McCaffrey',
#  54905: 'Jaylen Warren',
#  55897: 'Joey Porter Jr.',
#  53484: 'Pat Freiermuth',
#  53531: 'Ambry Thomas',
#  47931: 'Dre Greenlaw',
#  52532: 'Anthony McFarland',
#  46157: 'Oren Burks',
#  52510: 'Alex Highsmith',
#  46127: 'Isaiah Oliver',
#  54603: 'Calvin Austin III',
#  53453: 'Najee Harris',
#  54673: 'Connor Heyward',
#  46652: 'Chandon Sullivan',
#  42401: 'Markus Golden',
#  54637: 'Samuel Womack',
#  46968: 'Josh Woods',
#  52535: "K'Von Wallace",
#  56045: "Kei'Trel Clark",
#  54481: 'Jahan Dotson',
#  44848: 'Budda Baker',
#  49410: 'Jalen Thompson',
#  41349: 'Logan Thomas',
#  46188: 'Kyzir White',
#  53565: 'Marco Wilson',
#  44852: 'Curtis Samuel',
#  47871: 'Cody Barton',
#  52624: 'Kam Curl',
#  39983: 'Zach Ertz',
#  53503: 'Benjamin St-Juste',
#  53592: 'Darrick Forrest',
#  45102: 'Zach Pascal',
#  54563: 'Brian Robinson',
#  55880: 'Emmanuel Forbes',
#  53448: 'Jamin Davis',
#  53478: 'Rondale Moore',
#  52641: 'Casey Toohill',
#  43373: 'Kendall Fuller',
#  47808: 'Marquise Brown',
#  47859: 'Terry McLaurin',
#  53445: 'Zaven Collins',
#  54614: 'Cole Turner',
#  46657: 'Dennis Gardeck',
#  54520: 'Trey McBride',
#  43986: 'Antonio Hamilton',
#  54578: 'Percy Butler',
#  55959: 'Michael Wilson',
#  52637: 'James Smith-Williams',
#  46807: 'Andre Chachere',
#  44917: 'James Conner',
#  42381: 'Preston Smith',
#  44911: 'Rasul Douglas',
#  55998: 'Tyler Scott',
#  52458: 'Jaylon Johnson',
#  54504: 'Kyler Gordon',
#  54597: 'Romeo Doubs',
#  44925: 'Eddie Jackson',
#  48516: 'T.J. Edwards',
#  46085: 'Tremaine Edmunds',
#  55921: 'Tyrique Stevenson',
#  56024: 'Dontayvion Wicks',
#  47804: 'Darnell Savage',
#  46087: 'Jaire Alexander',
#  48241: 'Keisean Nixon',
#  52581: 'Darnell Mooney',
#  54487: 'Quay Walker',
#  53646: 'Khalil Herbert',
#  43404: "De'Vondre Campbell",
#  44901: "D'Onta Foreman",
#  56220: 'Malik Heath',
#  55907: 'Luke Musgrave',
#  45021: 'Rudy Ford',
#  46093: 'DJ Moore',
#  52451: 'Cole Kmet',
#  55915: 'Jayden Reed',
#  48207: 'Khari Blasingame',
#  52470: 'AJ Dillon',
#  54513: 'Jaquan Brisker',
#  54723: 'Samori Toure',
#  44995: 'Aaron Jones',
#  55980: 'Roschon Johnson',
#  54807: 'Josh Blackwell',
#  52457: 'Chase Claypool',
#  53649: 'Isaiah McDuffie',
#  46175: 'Josey Jewell',
#  53438: 'Pat Surtain II',
#  41282: 'Davante Adams',
#  42929: 'Alex Singleton',
#  54580: 'Damarri Mathis',
#  35459: 'Kareem Jackson',
#  48097: 'Jakobi Meyers',
#  42361: 'Marcus Peters',
#  53596: 'Nate Hobbs',
#  52513: 'Adam Trautman',
#  55969: 'Jakorian Bennett',
#  47974: 'Marcus Epps',
#  54967: 'Brandon Johnson',
#  53464: 'Javonte Williams',
#  46902: 'Robert Spillane',
#  53509: 'Divine Deablo',
#  53472: "Tre'von Moehrig",
#  54545: 'Greg Dulcich',
#  48541: "Lil'Jordan Humphrey",
#  47807: 'Josh Jacobs',
#  43387: 'Justin Simmons',
#  52764: 'Essang Bassey',
#  46109: 'Courtland Sutton',
#  44927: 'Samaje Perine',
#  42372: 'Phillip Dorsett',
#  42406: 'Frank Clark',
#  54587: 'Zamir White',
#  42397: 'Ameer Abdullah',
#  52547: 'Amik Robertson',
#  55928: 'Marvin Mims Jr.',
#  42511: 'Michael Burton',
#  55871: 'Tyree Wilson',
#  43370: 'Austin Hooper',
#  44893: 'Fabian Moreau',
#  46086: 'Derwin James',
#  46775: 'J.C. Jackson',
#  53435: 'Jaylen Waddle',
#  46259: 'DeShon Elliott',
#  40024: 'Keenan Allen',
#  47971: 'David Long Jr.',
#  43327: 'Xavien Howard',
#  42388: 'Eric Kendricks',
#  54544: 'JT Woods',
#  45571: 'Michael Davis',
#  43454: 'Tyreek Hill',
#  52431: 'Kenneth Murray, Jr.',
#  45900: 'River Cracraft',
#  52594: 'Alohi Gilman',
#  46192: 'Durham Smythe',
#  53476: 'Asante Samuel',
#  46279: 'Braxton Berrios',
#  46142: 'Jerome Baker',
#  52520: 'Joshua Kelley',
#  48233: 'Alec Ingold',
#  45573: 'Austin Ekeler',
#  48456: 'Donald Parham',
#  54679: "Ja'Sir Taylor",
#  54936: 'Kader Kohou',
#  53506: 'Josh Palmer',
#  38707: 'Justin Bethel',
#  43299: 'Eli Apple',
#  55885: 'Quentin Johnston',
#  47934: 'Andrew Van Ginkel',
#  44856: 'Gerald Everett',
#  53465: 'Jevon Holland',
#  55919: 'Tuli Tuipulotu',
#  42718: 'Raheem Mostert',
#  44819: 'Mike Williams',
#  52922: 'Salvon Ahmed',
#  53579: 'Kenneth Gainwell',
#  55941: 'Marte Mapu',
#  43700: 'Jonathan Jones',
#  52991: 'Myles Bryant',
#  52608: 'Quez Watkins',
#  46194: 'Avonte Maddox',
#  44862: 'Justin Evans',
#  44869: 'Zach Cunningham',
#  43324: 'Hunter Henry',
#  54548: 'Nakobe Dean',
#  56075: 'DeMario Douglas',
#  39984: 'Darius Slay',
#  45185: 'Kendrick Bourne',
#  55881: 'Christian Gonzalez',
#  47834: 'A.J. Brown',
#  54550: 'Marcus Jones',
#  53439: 'DeVonta Smith',
#  43351: 'James Bradberry',
#  44874: 'JuJu Smith-Schuster',
#  54808: 'Reed Blankenship',
#  44837: 'Jabrill Peppers',
#  52443: "D'Andre Swift",
#  54026: 'Christian Elliss',
#  46111: 'Mike Gesicki',
#  42437: 'Ty Montgomery',
#  46212: "Ja'Whaun Bentley",
#  52445: 'Kyle Dugger',
#  53549: 'Rhamondre Stevenson',
#  56052: 'Kayshon Boutte',
#  47826: 'Jahlani Tavai',
#  43435: 'Matthew Judon',
#  42116: 'Adrian Phillips',
#  52468: 'Joshua Uche',
#  43522: 'Jalen Mills',
#  46118: 'Dallas Goedert',
#  46097: 'Terrell Edmunds',
#  54815: 'Josh Jobe',
#  44878: 'Ahkello Witherspoon',
#  52835: 'Michael Hoecht',
#  42412: 'Tyler Lockett',
#  55942: 'Byron Young',
#  53532: 'Ernest Jones',
#  54718: 'Russ Yeast',
#  47847: 'DK Metcalf',
#  54607: 'Cobie Durant',
#  54677: 'Derion Kendrick',
#  54574: 'Coby Bryant',
#  52435: 'Jordyn Brooks',
#  42543: 'Quandre Diggs',
#  43399: 'Tyler Higbee',
#  53566: 'Tre Brown',
#  56042: 'Puka Nacua',
#  38577: 'Bobby Wagner',
#  47891: 'Julian Love',
#  52465: 'Van Jefferson',
#  54618: 'Riq Woolen',
#  52456: 'Darrell Taylor',
#  46189: 'Will Dissly',
#  54506: 'Kenneth Walker III',
#  52844: 'Christian Rozeboom',
#  55884: 'Jaxon Smith-Njigba',
#  52607: 'Jordan Fuller',
#  47793: 'Devin Bush',
#  52544: 'Brycen Hopkins',
#  55902: 'Derick Hall',
#  53486: 'Tutu Atwell',
#  52552: 'DeeJay Dallas',
#  43314: 'Artie Burns',
#  46117: 'Uchenna Nwosu',
#  52541: 'Colby Parkinson',
#  47941: 'Mike Jackson',
#  54629: 'Kyren Williams',
#  53678: 'Ben Skowronek',
#  54676: 'Quentin Lake',
#  55166: 'Juanyeh Thomas',
#  55149: 'Markquese Bell',
#  42547: 'Darren Waller',
#  54611: 'Micah McFadden',
#  56074: 'Tre Hawkins III',
#  52444: 'Xavier McKinney',
#  54594: 'Jake Ferguson',
#  44830: "Adoree' Jackson",
#  47872: 'Bobby Okereke',
#  55888: 'Deonte Banks',
#  53604: 'Jason Pinnock',
#  52425: 'CeeDee Lamb',
#  53117: 'KaVontae Turpin',
#  54632: 'DaRon Bland',
#  52459: 'Trevon Diggs',
#  46071: 'Saquon Barkley',
#  41246: 'Brandin Cooks',
#  54579: 'Dane Belton',
#  52416: 'Isaiah Simmons',
#  47911: 'Tony Pollard',
#  38540: 'Stephon Gilmore',
#  44827: 'Malik Hooker',
#  54641: 'Damone Clark',
#  52615: 'Isaiah Hodgins',
#  43533: 'Jayron Kearse',
#  46088: 'Leighton Vander Esch',
#  47842: 'Parris Campbell',
#  46150: 'Michael Gallup',
#  53854: 'Nick McCloud',
#  54470: 'Kayvon Thibodeaux',
#  55157: 'Peyton Hendershot',
#  47954: 'Darius Slayton',
#  52518: 'Darnay Holmes',
#  54577: 'Daniel Bellinger',
#  43329: 'Sterling Shepard',
#  52438: 'Noah Igbinoghene',
#  53047: 'Lawrence Cager',
#  42094: 'C.J. Goodwin',
#  53656: 'Israel Mukuamu',
#  54553: 'Jalen Tolbert',
#  47881: 'Quincy Williams',
#  54469: 'Sauce Gardner',
#  42489: 'Stefon Diggs',
#  46211: 'D.J. Reed',
#  54833: 'Tony Adams',
#  44976: 'Matt Milano',
#  40107: 'Micah Hyde',
#  44839: "Tre'Davious White",
#  54475: 'Garrett Wilson',
#  53536: 'Michael Carter',
#  42485: 'Adrian Amos',
#  48415: 'Deonte Harty',
#  47879: 'Dawson Knox',
#  52476: 'Ashtyn Davis',
#  41243: 'C.J. Mosley',
#  46186: 'Jordan Whitehead',
#  47870: 'Damien Harris',
#  44853: 'Dalvin Cook',
#  54650: 'Christian Benford',
#  40166: 'Jordan Poyer',
#  46190: 'Taron Johnson',
#  46705: 'Allen Lazard',
#  54528: 'James Cook',
#  53583: 'Michael Carter II',
#  55889: 'Dalton Kincaid',
#  52536: 'Gabe Davis',
#  46226: 'Tyler Conklin',
#  54554: 'Terrel Bernard',
#  37139: 'Randall Cobb',
#  40129: 'Latavius Murray',
#  54669: 'Theo Jackson',
#  45345: 'Nicholas Morrow',
#  54814: 'Mario Goodrich',
#  52525: 'D.J. Wonnum',
#  42431: 'Danielle Hunter',
#  46096: 'Rashaad Penny',
#  55175: 'Nate Landman',
#  44912: 'Jonnu Smith',
#  54644: 'Kingsley Enagbare',
#  52502: 'Josiah Deguara',
#  43298: 'Leonard Floyd',
#  47862: 'David Long',
#  53079: 'Reggie Gilliam',
#  55965: 'Tre Tucker',
#  42794: 'DeAndre Carter',
#  54613: 'Khalil Shakir',
#  55900: 'Michael Mayer',
#  48581: 'Roderic Teamer',
#  48487: 'Cam Lewis',
#  52647: 'Dane Jackson',
#  46223: 'Siran Neal',
#  47844: 'Taylor Rapp',
#  48482: 'Tyrel Dodson',
#  47932: 'Hunter Renfrow',
#  46155: 'Mark Andrews',
#  46146: 'Sam Hubbard',
#  41227: 'Jadeveon Clowney',
#  42363: 'Nelson Agholor',
#  52500: 'Devin Duvernay',
#  47965: 'Trayveon Williams',
#  55960: 'Jordan Battle',
#  47817: 'Rock Ya-Sin',
#  47896: 'Justice Hill',
#  55989: 'Tavius Robinson',
#  54682: 'James Houston',
#  55869: 'Devon Witherspoon',
#  56084: 'Antoine Green',
#  47803: 'Noah Fant',
#  53542: 'Derrick Barnes',
#  56471: 'Jake Bobo',
#  55917: 'Zach Charbonnet',
#  47856: 'David Montgomery',
#  43474: 'DeAndre Houston-Carson',
#  56027: 'Will Mallory',
#  52494: 'Zack Moss',
#  44957: 'Grover Stewart',
#  53576: 'Brevin Jordan',
#  47857: 'Devin Singletary',
#  54509: 'John Metchie III',
#  42377: 'Donovan Smith',
#  46700: 'Tre Herndon',
#  40011: 'Travis Kelce',
#  47605: "D'Ernest Johnson",
#  54708: 'Jaylen Watson',
#  44978: 'Jamal Agnew',
#  46153: 'Justin Jones',
#  46310: 'Greg Stroman',
#  54622: 'Zyon McCollum',
#  45635: 'Robert Tonyan',
#  54781: 'Jack Sanborn',
#  56141: 'Quindell Johnson',
#  56030: 'Terell Smith',
#  54719: 'Elijah Hicks',
#  54778: 'Jaylon Jones',
#  46759: 'David Wells',
#  54639: 'Dominique Robinson',
#  56541: 'Rakim Jarrett',
#  42031: 'Denico Autry',
#  55181: 'Tre Avery',
#  53614: 'Nick Niemann',
#  43334: 'Derrick Henry',
#  56582: 'Elijah Dotson',
#  55081: 'Mike Brown',
#  53564: 'Rashad Weaver',
#  41231: 'Khalil Mack',
#  56576: 'Brevin Allen',
#  47904: 'Trevon Wesco',
#  46156: 'Arden Key',
#  55061: 'Stone Smartt',
#  56395: 'Emari Demercado',
#  52863: 'Krys Barnes',
#  55938: 'Jalin Hyatt',
#  53639: 'Victor Dimukeje',
#  44903: 'John Johnson',
#  55145: 'Ronnie Rivers',
#  56077: 'Deuce Vaughn',
#  53575: 'Jamien Sherwood',
#  44904: 'Jourdan Lewis',
#  44174: 'Sam Eguavoen',
#  55923: 'Luke Schoonmaker',
#  54501: 'Breece Hall',
#  53629: 'Brandin Echols',
#  42346: 'Dante Fowler Jr.',
#  47839: 'Mecole Hardman',
#  53553: 'John Bates',
#  52423: 'Jerry Jeudy',
#  53511: 'Dyami Brown',
#  53668: 'Jonathon Cooper',
#  54617: 'Delarrin Turner-Yell',
#  52474: 'Antonio Gibson',
#  46522: 'Byron Pringle',
#  42357: 'DeVante Parker',
#  46074: 'Bradley Chubb',
#  53589: 'Shaun Wade',
#  55949: "De'Von Achane",
#  54590: 'Erik Ezukanma',
#  46542: 'Keith Kirkwood',
#  47920: 'Foster Moreau',
#  43497: 'Kamu Grugier-Hill',
#  37145: 'Justin Houston',
#  52762: 'Tony Jones',
#  46130: 'D.J. Chark',
#  37097: 'Cameron Jordan',
#  48988: 'Gunner Olszewski',
#  54621: 'Jerome Ford',
#  41464: 'Shelby Harris',
#  47863: 'Sione Takitaki',
#  47846: 'Juan Thornhill',
#  46229: 'Ogbo Okoronkwo',
#  56007: 'Cameron Mitchell',
#  47876: 'Miles Boykin',
#  52904: 'Elijah Riley',
#  54592: 'Pierre Strong',
#  54508: "Wan'Dale Robinson",
#  53625: 'Gary Brightwell',
#  47878: 'Oshane Ximines',
#  53623: 'Elijah Mitchell',
#  56118: 'Ronnie Bell',
#  45186: 'Matt Breida',
#  46349: 'George Odum',
#  54526: 'Drake Jackson',
#  55909: 'Julius Brents',
#  54857: 'Jeremiah Moon',
#  43366: 'Daryl Worley',
#  44985: 'Isaiah McKenzie',
#  53517: 'Trey Sermon',
#  42358: 'Melvin Gordon',
#  54541: 'Travis Jones',
#  54561: 'Nick Cross',
#  43362: 'Kenyan Drake',
#  44898: 'Kareem Hunt',
#  52411: 'Jeff Okudah',
#  46151: 'Tracy Walker III',
#  53530: 'Ifeatu Melifonwu',
#  33131: 'Calais Campbell',
#  46099: 'Mike Hughes',
#  42486: 'MyCole Pruitt',
#  46992: 'KhaDarel Hodge',
#  56097: 'Carrington Valentine',
#  35534: 'Jimmy Graham',
#  45215: 'Eric Wilson',
#  45244: 'Taysom Hill',
#  47837: 'Lonnie Johnson',
#  47963: 'Corey Ballentine',
#  56516: 'Emanuel Wilson',
#  52875: 'Patrick Taylor',
#  55893: 'Bryan Bresee',
#  41256: 'Jimmie Ward',
#  47940: 'Blake Cashman',
#  53707: 'Tim Jones',
#  54535: 'Chad Muma',
#  52428: "K'Lavon Chaisson",
#  56001: 'Yasir Abdullah',
#  43356: 'Maliek Collins',
#  55043: 'Jake Hansen',
#  55926: 'Brenton Strange',
#  42302: 'Chris Manhertz',
#  56502: 'Nate Adkins',
#  55932: 'Drew Sanders',
#  42403: 'Randy Gregory',
#  56410: 'Julian Hill',
#  52478: 'Brandon Jones',
#  53473: 'Kelvin Joseph',
#  44887: 'Duke Riley',
#  46248: 'Parry Nickerson',
#  43808: 'Robbie Chosen',
#  46501: 'Elijah Campbell',
#  54634: 'Ty Chandler',
#  55990: 'Derius Davis',
#  55054: 'Raheem Layne',
#  46264: 'Sebastian Joseph-Day',
#  46830: 'Brandon Powell',
#  45339: 'Pharaoh Brown',
#  42500: 'C.J. Uzomah',
#  43293: 'Ezekiel Elliott',
#  52495: 'Anfernee Jennings',
#  46671: 'Trent Sherfield',
#  53459: 'Greg Rousseau',
#  55956: 'Dorian Williams',
#  47799: 'Brian Burns',
#  52446: 'Yetur Gross-Matos',
#  52939: 'Sam Franklin Jr.',
#  43341: 'Deion Jones',
#  53512: 'Tommy Tremble',
#  46170: 'Ian Thomas',
#  56063: 'Jerrick Reed II',
#  44865: 'Teez Tabor',
#  47996: 'Donovan Wilson',
#  56457: 'Hunter Luepke',
#  46674: 'Ezekiel Turner',
#  53887: 'Malik Herring',
#  55984: 'Chamarri Conner',
#  55105: 'Luke Masterson',
#  55997: 'Nick Herbig',
#  48374: 'Olamide Zaccheaus',
#  55931: 'Sydney Brown',
#  53946: 'Jack Stoll',
#  55947: 'Yaya Diaby',
#  55894: 'Nolan Smith',
#  46699: 'Dee Delaney',
#  44825: 'Haason Reddick',
#  56547: 'Derrek Pitts',
#  55996: 'Charlie Jones',
#  46797: 'Tanner Hudson',
#  52673: 'Mitchell Wilcox',
#  55892: 'Myles Murphy',
#  47835: 'Drew Sample',
#  46630: 'Jalen Davis',
#  43775: 'Romeo Okwara',
#  54493: 'Devonte Wyatt',
#  54499: 'Christian Watson',
#  55877: 'Lukas Van Ness',
#  55943: 'Tucker Kraft',
#  47864: 'Will Harris',
#  53574: 'Luke Farrell',
#  56089: 'DeMarcco Hellams',
#  52548: 'Shaquille Quarterman',
#  52708: 'JaMycal Hasty',
#  46277: 'Cedrick Wilson Jr.',
#  56598: "D'Shawn Jamison",
#  52460: 'Cam Akers',
#  46165: 'Harrison Phillips',
#  54969: "Ja'Quan McMillian",
#  54529: 'Nik Bonitto',
#  46276: 'Equanimeous St. Brown',
#  56513: 'Jaleel McLaughlin',
#  46437: 'Gus Edwards',
#  45395: 'Arthur Maulet',
#  53582: 'Tony Fields II',
#  43507: 'Kevon Seymour',
#  45268: 'Patrick Ricard',
#  55939: 'Cedric Tillman',
#  48096: 'Andrew Beck',
#  55958: 'Darnell Washington',
#  55115: 'Segun Olubi',
#  44879: 'Alvin Kamara',
#  52482: 'Zack Baun',
#  53932: 'Adam Prentice',
#  46081: 'Vita Vea',
#  55936: 'Kendre Miller',
#  52484: "Ke'Shawn Vaughn",
#  47810: 'Johnathan Abram',
#  52488: 'Lynn Bowden',
#  52410: 'Chase Young',
#  56012: 'Josh Whyle',
#  52623: 'Markus Bailey',
#  56093: 'Colton Dowell',
#  53049: 'Shyheim Carter',
#  48471: 'Trenton Irwin',
#  54588: 'Isaiah Spiller',
#  42901: 'Dean Marlowe',
#  47749: 'Jakob Johnson',
#  53041: 'Rico Dowdle',
#  47938: 'Mack Wilson',
#  55113: 'Jordan Mason',
#  54721: 'Jesse Luketa',
#  46256: 'Ray-Ray McCloud',
#  41500: 'Willie Snead',
#  54552: 'Cameron Thomas',
#  40078: 'Kyle Juszczyk',
#  56081: 'Dee Winters',
#  48117: 'Demetrius Flannigan-Fowles',
#  47894: 'Kendall Sheffield',
#  56252: 'Xavier Gipson',
#  54566: 'Jeremy Ruckert',
#  52566: 'Bryce Hall',
#  48266: 'Cody Thompson',
#  54546: 'Cordale Flott',
#  54014: 'Jon Rhattigan',
#  46329: 'Danny Johnson',
#  42448: 'Jamison Crowder',
#  46148: 'Rasheem Green',
#  54488: 'Kaiir Elam',
#  55240: "Ja'Marcus Ingram",
#  56025: 'Antonio Johnson',
#  47968: "Ka'dar Hollman",
#  48599: 'Albert Huggins',
#  41808: 'Keith Smith',
#  39975: 'Cordarrelle Patterson',
#  42480: 'Grady Jarrett',
#  52498: 'Jonathan Greenard',
#  55148: 'Chandler Wooten',
#  54477: 'Jameson Williams',
#  52743: 'Benito Jones',
#  54835: 'Bam Knight',
#  56086: 'Jaylon Jones',
#  54628: 'Kyle Philips',
#  53688: 'Grant Stuard',
#  43296: 'DeForest Buckner',
#  56079: 'Ameer Speed',
#  44828: 'Marlon Humphrey',
#  42589: 'Geoff Swaim',
#  56028: 'Chase Brown',
#  56071: 'Andrei Iosivas',
#  53498: 'Joseph Ossai',
#  55005: 'Kwamie Lassiter',
#  44881: 'Cooper Kupp',
#  56242: 'Eli Ricks',
#  44826: 'Derek Barnett',
#  41257: 'Bradley Roby',
#  47988: 'Duke Shelley',
#  46083: 'Marcus Davenport',
#  52540: 'Troy Dye',
#  54507: 'Andrew Booth',
#  45094: 'Johnny Mundt',
#  46185: 'Dorance Armstrong',
#  55952: "Ji'Ayir Brown",
#  56529: 'Ben Sims',
#  52685: 'Tyler Hall',
#  45038: 'Isaac Rochell',
#  53525: 'Ronnie Perkins',
#  47991: 'Scott Miller',
#  52570: 'Khaleke Hudson',
#  55912: 'Quan Martin',
#  44990: 'Trent Taylor',
#  52501: 'Darrynton Evans',
#  54536: 'Velus Jones Jr.',
#  44818: 'Jamal Adams',
#  43455: 'DJ Reader',
#  46141: 'Nathan Shepherd',
#  55867: 'Will Anderson Jr.',
#  52449: 'Jonathan Taylor',
#  54687: 'Montaric Brown',
#  53514: 'Amari Rodgers',
#  43616: 'Matthias Farley',
#  55916: 'Cam Smith',
#  55014: 'Raheem Blackshear',
#  47975: 'Isaiah Buggs',
#  56036: 'Payne Durham',
#  52947: 'Cam Gill',
#  48318: 'Devine Ozigbo',
#  54467: 'Aidan Hutchinson',
#  52475: 'Julian Okwara',
#  54515: 'Tyquan Thornton',
#  54666: 'Keaontay Ingram',
#  41712: 'Damien Williams',
#  55906: 'BJ Ojulari',
#  56353: 'Starling Thomas V',
#  54819: 'Joey Blount',
#  55212: 'Jacob Hummel',
#  56047: 'Tre Tomlinson',
#  46199: 'Josh Sweat',
#  54491: 'Jermaine Johnson II',
#  48495: 'Tae Hayes',
#  46270: 'Boston Scott',
#  46535: 'Craig James',
#  56237: 'Mekhi Garner',
#  43333: 'Jihad Ward',
#  53855: 'Quintin Morris',
#  56461: 'Tyrus Wheat',
#  53441: 'Micah Parsons',
#  52934: 'Sean McKeon',
#  44880: 'Dawuane Smoot',
#  53028: 'Khalil Dorsey',
#  52479: 'Nnamdi Madubuike',
#  54584: 'Jalyn Armour-Davis',
#  48364: "Del'Shawn Phillips",
#  55100: 'Isaiah Pola-Mao',
#  30842: 'Marcedes Lewis',
#  43358: 'Yannick Ngakoue',
#  54968: "Kana'i Mauga",
#  48700: 'Jesper Horsted',
#  54586: 'Jack Jones',
#  52429: 'Jalen Reagor',
#  42512: 'David Mayo',
#  42365: 'Bud Dupree',
#  55940: 'Zach Harrison',
#  47853: 'Darrell Henderson',
#  52697: 'James Pierre',
#  55937: 'Garrett Williams',
#  56062: 'Elijah Higgins',
#  46669: 'Jonathan Owens',
#  56107: 'Anthony Johnson Jr.',
#  48447: 'P.J. Locke',
#  53534: 'Baron Browning',
#  52545: 'Josiah Scott',
#  37079: 'Julio Jones',
#  46377: 'Jeff Wilson',
#  53447: 'Jaelan Phillips',
#  52836: 'Trishton Jackson',
#  46203: 'Chase Edmonds',
#  35470: 'Jerry Hughes',
#  52659: 'Stephen Sullivan',
#  55945: 'DJ Johnson',
#  47970: 'Juwann Winfree',
#  43294: 'Jalen Ramsey',
#  48476: 'Nik Needham',
#  43400: 'Miles Killebrew',
#  55036: 'Rod Williams',
#  45018: 'Jeremiah Ledbetter',
#  43352: 'Adam Gotsis',
#  43787: 'Roy Robertson-Harris',
#  56673: 'Eric Garror',
#  46303: 'Andre Smith',
#  37792: 'Nick Bellore',
#  46209: 'Maurice Hurst',
#  47848: 'Zach Allen',
#  40039: 'Duron Harmon',
#  53608: 'Simi Fehoko',
#  52555: 'Khalid Kareem',
#  54701: 'Deane Leonard',
#  55950: 'Daiyan Henley',
#  56068: 'Amari Burney',
#  48707: 'Craig Reynolds',
#  56003: 'Darius Rush',
#  54877: 'Jack Cochrane',
#  42899: 'Damiere Byrd',
#  48206: 'Micah Abernathy',
#  46135: 'Lorenzo Carter',
#  54505: 'Boye Mafe',
#  54915: "D'Anthony Bell",
#  48780: 'Troy Reeder',
#  43415: 'Demarcus Robinson',
#  54054: 'Austin Trammell',
#  56013: 'Noah Sewell',
#  56010: 'Jammie Robinson',
#  56230: 'Alex Cook',
#  53883: 'Dicaprio Bootle',
#  54654: 'Amare Barno',
#  43323: 'Jaylon Smith',
#  43308: 'Shaq Lawson',
#  37075: 'Von Miller',
#  43292: 'Joey Bosa',
#  46306: 'Nick Bawden',
#  48556: 'Jalen Guyton',
#  48624: 'Malik Taylor',
#  56586: 'AJ Finley',
#  ...}

# %%
max_play_len
# Out:
# 123

# %% [markdown]
# #### Generate Input/Output Dataset for Justin Reid

# %%
player_id = 46137 # Justin Reid's NFL ID is 46137
justin_reid_input = dict()
justin_reid_output = dict()
justin_reid_labels = dict()

for clean_dfs in clean_input_dfs:
    for _,row in clean_dfs.iterrows():
        if row['nfl_id'] == player_id:
            id = row['unique_play_id']
            data = np.array([row['x'], row['y'], row['o'], row['v_x'], row['v_y'], row['a_x'], row['a_y']])
            if id not in justin_reid_input:
                justin_reid_input[id] = [data]
                justin_reid_output[id] = np.array([row['num_frames_output'], row['ball_land_x'], row['ball_land_y']])
                justin_reid_labels[id] = np.array([False])
            else:
                justin_reid_input[id].append(data)

for clean_dfs in clean_output_dfs:
    for _,row in clean_dfs.iterrows():
        if row['nfl_id'] == player_id:
            id = row['unique_play_id']
            data = np.array([row['frame_id'], row['x'], row['y']])
            if id not in justin_reid_output:
                print("Dataset Error, no corresponding play ID in input dataframe")
            else:
                justin_reid_output[id] = np.vstack((justin_reid_output[id], data))
                justin_reid_labels[id] = np.append(justin_reid_labels[id], True)
                land_info = justin_reid_output[id][0]
                landx = land_info[1]
                landy = land_info[2]
                if ((abs(landx-row['x'])<1) and (abs(landy-row['y'])<1)):
                    justin_reid_labels[id][0] = True

# %%
justin_reid_input['2023090700101']
# Out:
# [array([5.13200000e+01, 2.06900000e+01, 2.67680000e+02, 3.04739775e-01,
#         5.68653651e-02, 4.81685450e-01, 8.98839642e-02]),
#  array([ 5.13500000e+01,  2.06600000e+01,  2.68660000e+02,  3.17654412e-01,
#         -1.69397977e-01,  6.52956291e-01, -3.48206953e-01]),
#  array([ 51.39      ,  20.63      , 269.78      ,   0.3326258 ,
#          -0.28802791,   0.57453548,  -0.49750275]),
#  array([ 51.43      ,  20.61      , 269.78      ,   0.34236022,
#          -0.33643645,   0.44221528,  -0.43456374]),
#  array([ 51.48      ,  20.58      , 269.06      ,   0.41493343,
#          -0.34558682,   0.3380939 ,  -0.28158926]),
#  array([ 5.15800000e+01,  2.06300000e+01,  2.74000000e+02,  6.01493056e-01,
#         -1.01518981e-01,  2.85955715e-01, -4.82631221e-02]),
#  array([ 5.16500000e+01,  2.06200000e+01,  2.74900000e+02,  6.82024308e-01,
#         -1.04608044e-01,  4.84336103e-01, -7.42868716e-02]),
#  array([ 5.17300000e+01,  2.06000000e+01,  2.77780000e+02,  8.65265740e-01,
#         -9.06377338e-02,  1.00450391e+00, -1.05223116e-01]),
#  array([ 5.18200000e+01,  2.05900000e+01,  2.79150000e+02,  9.81027006e-01,
#         -1.32988775e-01,  9.01752096e-01, -1.22242207e-01]),
#  array([ 5.19200000e+01,  2.05800000e+01,  2.78450000e+02,  1.12859892e+00,
#         -1.60824385e-01,  9.99899041e-01, -1.42484762e-01]),
#  array([ 5.20400000e+01,  2.05700000e+01,  2.77080000e+02,  1.21642338e+00,
#         -2.87774482e-01,  1.11910951e+00, -2.64752523e-01]),
#  array([ 52.16      ,  20.53      , 272.        ,   1.44415227,
#          -0.58993577,   1.50895398,  -0.61640724]),
#  array([ 52.31      ,  20.46      , 267.81      ,   1.56336875,
#          -0.76385742,   1.32077705,  -0.64532782]),
#  array([ 52.48      ,  20.38      , 261.76      ,   1.73405069,
#          -0.89194631,   1.16492636,  -0.59920496]),
#  array([ 52.67      ,  20.28      , 256.68      ,   1.90777058,
#          -1.07541221,   1.12375527,  -0.63346198]),
#  array([ 52.86      ,  20.17      , 248.39      ,   2.05103092,
#          -1.18750669,   1.11638392,  -0.6463644 ]),
#  array([ 53.08      ,  20.04      , 240.07      ,   2.22563145,
#          -1.32463756,   1.151485  ,  -0.68533372]),
#  array([ 53.32      ,  19.88      , 233.86      ,   2.43736893,
#          -1.57137923,   1.34475527,  -0.86696785]),
#  array([ 53.58      ,  19.7       , 223.89      ,   2.60414922,
#          -1.9108393 ,   1.59635154,  -1.17135041]),
#  array([ 53.85      ,  19.49      , 214.56      ,   2.75876727,
#          -2.20229498,   1.74279065,  -1.3912515 ]),
#  array([ 54.13      ,  19.25      , 206.88      ,   2.93271146,
#          -2.54039436,   1.88207514,  -1.63030463]),
#  array([ 54.44      ,  18.98      , 202.44      ,   3.09656321,
#          -2.80779206,   1.81497126,  -1.64571544]),
#  array([ 54.76      ,  18.69      , 200.96      ,   3.3032326 ,
#          -3.07062769,   1.73584507,  -1.61361145]),
#  array([ 55.1       ,  18.37      , 192.82      ,   3.47948943,
#          -3.30653191,   1.63101067,  -1.54993683]),
#  array([ 55.45      ,  18.03      , 187.56      ,   3.64951066,
#          -3.51937096,   1.46844216,  -1.41607825]),
#  array([ 55.82      ,  17.67      , 184.99      ,   3.83025141,
#          -3.72085664,   1.29109598,  -1.25422134])]

# %%
justin_reid_output['2023090700101']
# Out:
# array([[21.        , 63.25999832, -0.22      ],
#        [ 1.        , 56.22      , 17.28      ],
#        [ 2.        , 56.63      , 16.88      ],
#        [ 3.        , 57.06      , 16.46      ],
#        [ 4.        , 57.48      , 16.02      ],
#        [ 5.        , 57.91      , 15.56      ],
#        [ 6.        , 58.34      , 15.1       ],
#        [ 7.        , 58.75      , 14.57      ],
#        [ 8.        , 59.14      , 14.01      ],
#        [ 9.        , 59.51      , 13.41      ],
#        [10.        , 59.86      , 12.8       ],
#        [11.        , 60.19      , 12.15      ],
#        [12.        , 60.5       , 11.46      ],
#        [13.        , 60.78      , 10.75      ],
#        [14.        , 61.05      , 10.02      ],
#        [15.        , 61.32      ,  9.26      ],
#        [16.        , 61.59      ,  8.48      ],
#        [17.        , 61.84      ,  7.69      ],
#        [18.        , 62.1       ,  6.9       ],
#        [19.        , 62.36      ,  6.13      ],
#        [20.        , 62.61      ,  5.38      ],
#        [21.        , 62.87      ,  4.63      ]])

# %%
justin_reid_labels['2023090700101']
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %% [markdown]
# #### Pad Dataset Such that all Input Sequences are of Same Length

# %%
max_seq_len = 0
for key in justin_reid_input.keys():
    max_seq_len = max(max_seq_len, len(justin_reid_input[key]))
print(max_seq_len)
# Out:
# 54

# %%
padded_justin_reid_input = dict()
for key in justin_reid_input.keys():
    pad_len = max_play_len - len(justin_reid_input[key])
    x = justin_reid_input[key][0][0]
    y = justin_reid_input[key][0][1]
    o = justin_reid_input[key][0][2]
    vx = justin_reid_input[key][0][3]
    vy = justin_reid_input[key][0][4]
    ax = justin_reid_input[key][0][5]
    ay = justin_reid_input[key][0][6]
    dt = 0.1
    start_x = x + vx*dt + 0.5*ax*dt**2
    start_y = y + vy*dt + 0.5*ay*dt**2
    padding = np.array([start_x, start_y, o, 0, 0, 0, 0])
    padding = np.tile(padding, (pad_len, 1))
    pad_data = np.concatenate((padding, justin_reid_input[key]))
    padded_justin_reid_input[key] = pad_data

# %%
training_ex = torch.from_numpy(padded_justin_reid_input['2023090700361'])
training_ex.shape
# Out:
# torch.Size([123, 7])

# %% [markdown]
# #### Generate Torch Training Tensors

# %%
input_sequences = []
input_destinations = []
output_sequences = []
output_label = []

oversample_ratio = 3

for key in justin_reid_input.keys():
    input_seq = padded_justin_reid_input[key]
    output_seq = justin_reid_output[key]
    labels = justin_reid_labels[key]

    for i in range(oversample_ratio):
        input_sequences.append(input_seq)
        input_destinations.append(output_seq[0])
        output_sequences.append(output_seq[1:])
        output_label.append(labels[0])

    rand_timestamps = np.random.randint(1, len(output_seq), len(output_seq)//2)
    for timestamp in rand_timestamps:
        input_sequences.append(input_seq)
        input_destinations.append(output_seq[timestamp])
        output_sequences.append(output_seq[1:])
        output_label.append(labels[timestamp])

# %%
output_frequency = {}

for item in output_label:
    if item in output_frequency:
        output_frequency[item] += 1
    else:
        output_frequency[item] = 1

for value, count in output_frequency.items():
    print(f"Value: {value}, Frequency: {count}")
# Out:
# Value: False, Frequency: 333
# Value: True, Frequency: 793

# %%
input_seq_tensor = torch.from_numpy(np.array(input_sequences))
input_seq_tensor = input_seq_tensor.to(torch.float32)
print(input_seq_tensor.shape)
input_target_tensor = torch.from_numpy(np.array(input_destinations))
input_target_tensor = input_target_tensor.to(torch.float32)
print(input_target_tensor.shape)
output_tensor = torch.tensor(output_label)
output_tensor = torch.unsqueeze(output_tensor, 1)
output_tensor = output_tensor.to(torch.float32)
print(output_tensor.shape)
print(len(output_sequences))
# Out:
# torch.Size([1126, 123, 7])
# torch.Size([1126, 3])
# torch.Size([1126, 1])
# 1126

# %% [markdown]
# #### Training Loop

# %%
batch_size = 32
num_epochs = 50
learning_rate = 1e-3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
dataset = list(zip(input_seq_tensor, input_target_tensor, output_tensor))

# --- Train/Validation Split ---
n_total = len(dataset)
n_train = int(0.7 * n_total)
n_val = int(0.15 * n_total)
n_test = n_total - n_train - n_val

train_dataset, val_dataset, test_dataset = random_split(dataset, [n_train, n_val, n_test])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
model = ReachabilityModel(
    motion_input_dim=7, lstm_hidden_dim=32, fc_hidden_dim=32
).to(device)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_acc = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    total, correct = 0, 0
    for seq_tensor, target_tensor, batch_output in train_loader:
        seq_tensor = seq_tensor.to(device)
        target_tensor = target_tensor.to(device)
        batch_output = batch_output.to(device)

        # Forward pass
        y_pred = model(seq_tensor, target_tensor)
        loss = criterion(y_pred.squeeze(), batch_output.squeeze())
        preds = (y_pred > 0.5).float()
        correct += (preds == batch_output).sum().item()
        total += batch_output.numel()

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    avg_train_loss = epoch_loss / len(train_loader.dataset)
    avg_train_acc = correct / total
    train_acc.append(avg_train_acc)

    # --- Validation phase ---
    model.eval()
    total, correct = 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for seq_tensor, target_tensor, batch_output in val_loader:
            seq_tensor = seq_tensor.to(device)
            target_tensor = target_tensor.to(device)
            batch_output = batch_output.to(device)

            y_pred = model(seq_tensor, target_tensor)
            preds = (y_pred > 0.5).float()
            correct += (preds == batch_output).sum().item()
            total += batch_output.numel()

            all_preds.append(preds.cpu())
            all_labels.append(batch_output.cpu())


    avg_val_acc = correct / total
    val_acc.append(avg_val_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {avg_train_loss:.4f} | "
          f"Train Acc: {avg_train_acc:.4f} | "
          f"Val Acc: {avg_val_acc:.4f} | ")
# Out:
# Epoch [1/50] Train Loss: 0.0128 | Train Acc: 0.5622 | Val Acc: 0.6845 |
# Epoch [2/50] Train Loss: 0.0112 | Train Acc: 0.6726 | Val Acc: 0.6845 |
# Epoch [3/50] Train Loss: 0.0104 | Train Acc: 0.6853 | Val Acc: 0.6786 |
# Epoch [4/50] Train Loss: 0.0103 | Train Acc: 0.6739 | Val Acc: 0.6786 |
# Epoch [5/50] Train Loss: 0.0101 | Train Acc: 0.6916 | Val Acc: 0.6786 |
# Epoch [6/50] Train Loss: 0.0097 | Train Acc: 0.7081 | Val Acc: 0.6786 |
# Epoch [7/50] Train Loss: 0.0099 | Train Acc: 0.7005 | Val Acc: 0.6786 |
# Epoch [8/50] Train Loss: 0.0098 | Train Acc: 0.6967 | Val Acc: 0.6845 |
# Epoch [9/50] Train Loss: 0.0099 | Train Acc: 0.6954 | Val Acc: 0.6845 |
# Epoch [10/50] Train Loss: 0.0095 | Train Acc: 0.7094 | Val Acc: 0.6845 |
# Epoch [11/50] Train Loss: 0.0098 | Train Acc: 0.6942 | Val Acc: 0.6845 |
# Epoch [12/50] Train Loss: 0.0096 | Train Acc: 0.7043 | Val Acc: 0.6845 |
# Epoch [13/50] Train Loss: 0.0096 | Train Acc: 0.7094 | Val Acc: 0.7083 |
# Epoch [14/50] Train Loss: 0.0094 | Train Acc: 0.7195 | Val Acc: 0.6964 |
# Epoch [15/50] Train Loss: 0.0093 | Train Acc: 0.7259 | Val Acc: 0.7024 |
# Epoch [16/50] Train Loss: 0.0096 | Train Acc: 0.7132 | Val Acc: 0.7024 |
# Epoch [17/50] Train Loss: 0.0094 | Train Acc: 0.7043 | Val Acc: 0.7083 |
# Epoch [18/50] Train Loss: 0.0093 | Train Acc: 0.7043 | Val Acc: 0.7024 |
# Epoch [19/50] Train Loss: 0.0091 | Train Acc: 0.7297 | Val Acc: 0.6964 |
# Epoch [20/50] Train Loss: 0.0092 | Train Acc: 0.7208 | Val Acc: 0.7083 |
# Epoch [21/50] Train Loss: 0.0089 | Train Acc: 0.7119 | Val Acc: 0.7083 |
# Epoch [22/50] Train Loss: 0.0089 | Train Acc: 0.7322 | Val Acc: 0.7262 |
# Epoch [23/50] Train Loss: 0.0089 | Train Acc: 0.7081 | Val Acc: 0.7143 |
# Epoch [24/50] Train Loss: 0.0089 | Train Acc: 0.7145 | Val Acc: 0.7619 |
# Epoch [25/50] Train Loss: 0.0091 | Train Acc: 0.7132 | Val Acc: 0.7262 |
# Epoch [26/50] Train Loss: 0.0087 | Train Acc: 0.7398 | Val Acc: 0.7024 |
# Epoch [27/50] Train Loss: 0.0087 | Train Acc: 0.7221 | Val Acc: 0.7262 |
# Epoch [28/50] Train Loss: 0.0090 | Train Acc: 0.7284 | Val Acc: 0.7143 |
# Epoch [29/50] Train Loss: 0.0085 | Train Acc: 0.7398 | Val Acc: 0.7440 |
# Epoch [30/50] Train Loss: 0.0086 | Train Acc: 0.7284 | Val Acc: 0.7262 |
# Epoch [31/50] Train Loss: 0.0084 | Train Acc: 0.7437 | Val Acc: 0.7381 |
# Epoch [32/50] Train Loss: 0.0083 | Train Acc: 0.7475 | Val Acc: 0.7560 |
# Epoch [33/50] Train Loss: 0.0085 | Train Acc: 0.7373 | Val Acc: 0.6905 |
# Epoch [34/50] Train Loss: 0.0086 | Train Acc: 0.7386 | Val Acc: 0.7381 |
# Epoch [35/50] Train Loss: 0.0084 | Train Acc: 0.7411 | Val Acc: 0.7202 |
# Epoch [36/50] Train Loss: 0.0087 | Train Acc: 0.7310 | Val Acc: 0.7024 |
# Epoch [37/50] Train Loss: 0.0084 | Train Acc: 0.7348 | Val Acc: 0.7202 |
# Epoch [38/50] Train Loss: 0.0084 | Train Acc: 0.7322 | Val Acc: 0.7262 |
# Epoch [39/50] Train Loss: 0.0082 | Train Acc: 0.7437 | Val Acc: 0.7143 |
# Epoch [40/50] Train Loss: 0.0080 | Train Acc: 0.7589 | Val Acc: 0.7560 |
# Epoch [41/50] Train Loss: 0.0076 | Train Acc: 0.7614 | Val Acc: 0.7262 |
# Epoch [42/50] Train Loss: 0.0079 | Train Acc: 0.7462 | Val Acc: 0.7321 |
# Epoch [43/50] Train Loss: 0.0078 | Train Acc: 0.7500 | Val Acc: 0.7381 |
# Epoch [44/50] Train Loss: 0.0077 | Train Acc: 0.7449 | Val Acc: 0.7321 |
# Epoch [45/50] Train Loss: 0.0078 | Train Acc: 0.7411 | Val Acc: 0.7381 |
# Epoch [46/50] Train Loss: 0.0078 | Train Acc: 0.7690 | Val Acc: 0.7321 |
# Epoch [47/50] Train Loss: 0.0079 | Train Acc: 0.7513 | Val Acc: 0.7083 |
# Epoch [48/50] Train Loss: 0.0078 | Train Acc: 0.7652 | Val Acc: 0.7321 |
# Epoch [49/50] Train Loss: 0.0077 | Train Acc: 0.7640 | Val Acc: 0.7321 |
# Epoch [50/50] Train Loss: 0.0077 | Train Acc: 0.7652 | Val Acc: 0.7202 |

# %%
plt.plot(train_acc)
plt.plot(val_acc)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.title('Acc vs Epochs Training')
plt.show()

# %%
model.eval()
total, correct = 0, 0
all_preds, all_labels = [], []
with torch.no_grad():
    for seq_tensor, target_tensor, batch_output in val_loader:
        seq_tensor = seq_tensor.to(device)
        target_tensor = target_tensor.to(device)
        batch_output = batch_output.to(device)

        y_pred = model(seq_tensor, target_tensor)
        preds = (y_pred > 0.5).float()
        correct += (preds == batch_output).sum().item()
        total += batch_output.numel()

        all_preds.append(preds.cpu())
        all_labels.append(batch_output.cpu())

all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Not Reachable", "Reachable"])
disp.plot(cmap="Blues", values_format="d")
plt.title("Test Set Confusion Matrix")
plt.show()

# %% [markdown]
# #### Probabilistic Gaussian Modeling

# %%
id = 40

eg_input = input_seq_tensor[id]
eg_target = input_target_tensor[id]
eg_output = output_tensor[id]
eg_outseq = output_sequences[id]

# %%
eg_input
# Out:
# tensor([[ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5407e+01,  1.8113e+01,  9.5960e+01,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 6.5270e+01,  1.8100e+01,  9.5960e+01,  1.3537e+00,  1.3082e-01,
#           3.7824e-01,  3.6553e-02],
#         [ 6.5410e+01,  1.8120e+01,  9.5150e+01,  1.4228e+00,  1.4327e-01,
#           3.4824e-01,  3.5066e-02],
#         [ 6.5560e+01,  1.8130e+01,  9.6160e+01,  1.4770e+00,  9.3446e-02,
#           3.8922e-01,  2.4624e-02],
#         [ 6.5710e+01,  1.8130e+01,  9.8230e+01,  1.5494e+00,  4.4360e-02,
#           5.0979e-01,  1.4596e-02],
#         [ 6.5870e+01,  1.8120e+01,  9.8230e+01,  1.6675e+00, -9.1767e-02,
#           8.7867e-01, -4.8356e-02],
#         [ 6.6050e+01,  1.8090e+01,  9.8230e+01,  1.7569e+00, -3.9143e-01,
#           1.4739e+00, -3.2837e-01],
#         [ 6.6230e+01,  1.8010e+01,  9.7630e+01,  1.8510e+00, -8.3344e-01,
#           2.3161e+00, -1.0428e+00],
#         [ 6.6420e+01,  1.7900e+01,  9.9260e+01,  1.9331e+00, -1.2089e+00,
#           2.4079e+00, -1.5058e+00],
#         [ 6.6620e+01,  1.7760e+01,  9.7510e+01,  1.9958e+00, -1.5711e+00,
#           2.1922e+00, -1.7257e+00],
#         [ 6.6820e+01,  1.7590e+01,  9.7510e+01,  2.0234e+00, -1.8327e+00,
#           1.8381e+00, -1.6649e+00],
#         [ 6.6990e+01,  1.7330e+01,  1.0194e+02,  1.8411e+00, -2.4691e+00,
#           1.8590e+00, -2.4932e+00],
#         [ 6.7160e+01,  1.7060e+01,  1.0594e+02,  1.7004e+00, -2.7814e+00,
#           1.4657e+00, -2.3975e+00],
#         [ 6.7320e+01,  1.6780e+01,  1.1348e+02,  1.4840e+00, -2.9251e+00,
#           1.1447e+00, -2.2562e+00],
#         [ 6.7460e+01,  1.6480e+01,  1.2675e+02,  1.2180e+00, -3.0670e+00,
#           8.7845e-01, -2.2119e+00],
#         [ 6.7570e+01,  1.6170e+01,  1.3628e+02,  8.5983e-01, -3.1757e+00,
#           8.3631e-01, -3.0888e+00],
#         [ 6.7640e+01,  1.5850e+01,  1.4258e+02,  2.7692e-01, -3.1780e+00,
#           3.6893e-01, -4.2340e+00],
#         [ 6.7650e+01,  1.5530e+01,  1.3529e+02, -3.8263e-01, -3.0763e+00,
#          -5.9492e-01, -4.7831e+00],
#         [ 6.7580e+01,  1.5230e+01,  1.3279e+02, -9.7969e-01, -2.9833e+00,
#          -1.4633e+00, -4.4559e+00],
#         [ 6.7460e+01,  1.4940e+01,  1.2696e+02, -1.5324e+00, -2.7978e+00,
#          -2.1425e+00, -3.9117e+00],
#         [ 6.7270e+01,  1.4670e+01,  1.2451e+02, -2.1505e+00, -2.5556e+00,
#          -2.8394e+00, -3.3743e+00],
#         [ 6.7020e+01,  1.4430e+01,  9.7460e+01, -2.6850e+00, -2.3830e+00,
#          -3.1487e+00, -2.7946e+00],
#         [ 6.6720e+01,  1.4200e+01,  7.3470e+01, -3.1751e+00, -2.2125e+00,
#          -3.1998e+00, -2.2297e+00],
#         [ 6.6380e+01,  1.3990e+01,  5.7650e+01, -3.5844e+00, -1.9697e+00,
#          -3.1287e+00, -1.7193e+00],
#         [ 6.6000e+01,  1.3820e+01,  3.7260e+01, -3.9253e+00, -1.6808e+00,
#          -2.9784e+00, -1.2753e+00],
#         [ 6.5570e+01,  1.3670e+01,  7.3900e+00, -4.3059e+00, -1.4391e+00,
#          -2.9401e+00, -9.8262e-01],
#         [ 6.5120e+01,  1.3530e+01,  3.5949e+02, -4.5967e+00, -1.2739e+00,
#          -2.6212e+00, -7.2643e-01],
#         [ 6.4650e+01,  1.3410e+01,  3.5507e+02, -4.8194e+00, -1.1295e+00,
#          -2.2296e+00, -5.2253e-01],
#         [ 6.4160e+01,  1.3300e+01,  3.5309e+02, -4.9710e+00, -1.0466e+00,
#          -1.6048e+00, -3.3789e-01],
#         [ 6.3660e+01,  1.3190e+01,  3.5220e+02, -5.0694e+00, -1.0646e+00,
#          -8.6121e-01, -1.8086e-01],
#         [ 6.3150e+01,  1.3080e+01,  3.5220e+02, -5.1523e+00, -1.1074e+00,
#          -4.0085e-01, -8.6154e-02],
#         [ 6.2630e+01,  1.2970e+01,  3.5136e+02, -5.1828e+00, -1.2004e+00,
#          -4.3840e-01, -1.0153e-01],
#         [ 6.2110e+01,  1.2840e+01,  3.4808e+02, -5.2229e+00, -1.2906e+00,
#          -6.6014e-01, -1.6312e-01],
#         [ 6.1580e+01,  1.2710e+01,  3.4269e+02, -5.2295e+00, -1.4621e+00,
#          -1.0690e+00, -2.9887e-01]])

# %%
landx = eg_target[1].item()
landy = eg_target[2].item()
marker = 'x' if eg_output == 0 else 'o'
print(eg_target)
print(marker)

trajectx_before = []
trajecty_before = []
trajectx_after = []
trajecty_after = []
for point in eg_input:
    trajectx_before.append(point[0].numpy())
    trajecty_before.append(point[1].numpy())
for point in eg_outseq:
    trajectx_after.append(point[1])
    trajecty_after.append(point[2])

centerx = int(eg_input[-1][0].item())
centery = int(eg_input[-1][1].item())
print(eg_input[-1])

startx = max(centerx-15, 0)
endx = min(centerx+15, 120)
starty = max(centery-15, 0)
endy = min(centery+15, 53)
# Out:
# tensor([12.0000, 52.9600, 15.2400])
# x
# tensor([ 6.1580e+01,  1.2710e+01,  3.4269e+02, -5.2295e+00, -1.4621e+00,
#         -1.0690e+00, -2.9887e-01])

# %%
targets = []
coords_x = []
coords_y = []
for i in range(startx, endx):
    for j in range(starty, endy):
        targets.append([10.0, i, j])
        coords_x.append(i)
        coords_y.append(j)
targets = torch.tensor(targets)
coords_x = np.array(coords_x)
coords_y = np.array(coords_y)

# %%
eg_input_list = [eg_input for _ in range(len(targets))]
stacked_eg_input = torch.stack(eg_input_list, dim=0)
stacked_eg_input.shape
# Out:
# torch.Size([810, 123, 7])

# %%
probs = []
model.eval()
with torch.no_grad():
    probs = model(stacked_eg_input.to(device), targets.to(device))
probs = torch.squeeze(probs).cpu().numpy()

# %%
# Create a regular grid to interpolate the data
xi = np.linspace(min(coords_x), max(coords_x), 200)
yi = np.linspace(min(coords_y), max(coords_y), 200)
xi, yi = np.meshgrid(xi, yi)

# Interpolate using griddata (cubic gives smoother results)
zi = griddata((coords_x, coords_y), probs, (xi, yi), method='cubic')

# Plot the heatmap
plt.figure(figsize=(8, 6))
heatmap = plt.pcolormesh(xi, yi, zi, cmap='viridis', shading='auto')
plt.scatter(coords_x, coords_y, c=probs, cmap='viridis', edgecolors='k', s=30)  # optional: overlay original points
plt.colorbar(heatmap, label='Probability')
plt.plot(trajectx_before, trajecty_before, color='k')
plt.plot(trajectx_after, trajecty_after, color='r')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Probability Heat Map')
plt.show()
